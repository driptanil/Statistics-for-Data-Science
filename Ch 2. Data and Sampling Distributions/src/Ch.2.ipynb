# %%
import pandas as pd

# %%
player_data_import = pd.read_csv('../data/players.csv')
player_data_import
# Out:
#       nflId height  weight   birthDate          collegeName Position  \
# 0     42901    6-1     208  1992-07-25        James Madison       SS
# 1     43501    6-0     220  1994-08-11     Central Michigan       FS
# 2     43534    6-0     205  1993-06-02             Illinois       SS
# 3     43535    6-1     235  1992-12-22               Temple      MLB
# 4     44174    6-1     236  1993-02-22           Texas Tech      ILB
# ...     ...    ...     ...         ...                  ...      ...
# 2727  33216    6-3     320  06/16/1986      Central Florida        G
# 2728  33184    6-3     265  05/02/1985  Winston-Salem State       DE
# 2729  45651    5-9     198  06/16/1993                 Iowa       WR
# 2730  41284     73     230  1992-10-20                  LSU       RB
# 2731  42849   5-10     205  12/14/1992           Texas Tech       WR
#
#             displayName
# 0          Dean Marlowe
# 1         Kavon Frazier
# 2     Clayton Fejedelem
# 3      Tyler Matakevich
# ...

# %%
def heightInches(height):
    my_list = height.split('-')
    if len(my_list) == 1:
        return int (my_list[0])
    else:
        return int (my_list[0]) * 12 + int (my_list[1])

# %%
player_data_import['height_inches'] = player_data_import['height'].apply(heightInches)

# %%
player_data_import
# Out:
#       nflId height  weight   birthDate          collegeName Position  \
# 0     42901    6-1     208  1992-07-25        James Madison       SS
# 1     43501    6-0     220  1994-08-11     Central Michigan       FS
# 2     43534    6-0     205  1993-06-02             Illinois       SS
# 3     43535    6-1     235  1992-12-22               Temple      MLB
# 4     44174    6-1     236  1993-02-22           Texas Tech      ILB
# ...     ...    ...     ...         ...                  ...      ...
# 2727  33216    6-3     320  06/16/1986      Central Florida        G
# 2728  33184    6-3     265  05/02/1985  Winston-Salem State       DE
# 2729  45651    5-9     198  06/16/1993                 Iowa       WR
# 2730  41284     73     230  1992-10-20                  LSU       RB
# 2731  42849   5-10     205  12/14/1992           Texas Tech       WR
#
#             displayName  height_inches
# 0          Dean Marlowe             73
# 1         Kavon Frazier             72
# ...

# %%
import matplotlib.pyplot as plt

sample_amount = range(10, 100, 20)

for x in sample_amount:
    samples = []
    for i in range(1000):
        samples.append(player_data_import['height_inches'].sample(x).mean())
    plt.hist(samples)

plt.legend([str(z) + " samples" for z in sample_amount])
plt.title("Central Limit Theorem")
# Out:
# Text(0.5, 1.0, 'Central Limit Theorem')
